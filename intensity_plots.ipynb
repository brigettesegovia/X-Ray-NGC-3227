# %%
# !python -m pip install --user astropy

# %%
import matplotlib.pyplot as plt

from astropy.visualization import astropy_mpl_style

plt.style.use(astropy_mpl_style)

from astropy.utils.data import get_pkg_data_filename
from astropy.wcs import WCS
from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename

image_file1 = get_pkg_data_filename('rh701299n00_im_2.fits')
image_file2 = get_pkg_data_filename('cutout-CDS_P_SDSS9_color.fits')
image_file3 = get_pkg_data_filename('cutout-xcatdb_P_XMM_PN_color.fits')

# %%
fits.info(image_file1), fits.info(image_file2), fits.info(image_file3)
# Out:
# Filename: rh701299n00_im_2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      59   (512, 512)   int16
# Filename: cutout-CDS_P_SDSS9_color.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      25   (1200, 900, 3)   uint8
# Filename: cutout-xcatdb_P_XMM_PN_color.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      27   (1200, 900, 4)   uint8
# (None, None, None)

# %%
image_data1 = fits.getdata(image_file1, ext=0)
image_data2 = fits.getdata(image_file2, ext=0)
image_data3 = fits.getdata(image_file3, ext=0)

# %%
image_file1 = get_pkg_data_filename('rh701299n00_im_2.fits')
image_file2 = get_pkg_data_filename('cutout-CDS_P_SDSS9_color.fits')


# filename = get_pkg_data_filename('galactic_center/gc_msx_e.fits')

# hdu = fits.open(filename)[0]
# wcs = WCS(hdu.header)


hdu1 = fits.open(image_file1)[0]
wcs1 = WCS(hdu1.header)
hdu2 = fits.open(image_file2)[0]
wcs2 = WCS(hdu2.header)

plt.subplot(projection=wcs2, slices=[0,'y', 'x'])
plt.imshow(hdu2.data[0,:,:], origin='lower')
plt.imshow(hdu2.data[1,:,:], origin='lower')
plt.imshow(hdu2.data[2,:,:], origin='lower')

#plt.contour(hdu1.data, colors='w', levels=np.linspace(3, 151, 5), alpha=1)
# plt.imshow(hdu1.data, origin='lower')
# plt.imshow(hdu2.data, vmin=-2.e-5, vmax=2.e-4, origin='lower')
plt.grid(color='white', ls='solid')
plt.xlabel('Galactic Longitude')
plt.ylabel('Galactic Latitude')

# %%
wcs1
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 155.88  19.86
# CRPIX : 256.375  256.375
# PC1_1 PC1_2  : 1.0  0.0
# PC2_1 PC2_2  : 0.0  1.0
# CDELT : -0.000555556  0.000555556
# NAXIS : 512  512

# %%
image_file1 = get_pkg_data_filename('rh701299n00_im_2.fits')
image_file2 = get_pkg_data_filename('cutout-CDS_P_SDSS9_color.fits')


# filename = get_pkg_data_filename('galactic_center/gc_msx_e.fits')

# hdu = fits.open(filename)[0]
# wcs = WCS(hdu.header)


hdu1 = fits.open(image_file1)[0]
wcs1 = WCS(hdu1.header)
hdu2 = fits.open(image_file2)[0]
wcs2 = WCS(hdu2.header)

plt.subplot(projection=wcs1)
# plt.imshow(hdu2.data[0,:,:], origin='lower')
# plt.imshow(hdu2.data[1,:,:], origin='lower')
# plt.imshow(hdu2.data[2,:,:], origin='lower')
plt.imshow(hdu1.data, origin='lower', vmin=0, vmax=1, cmap='Greys')
plt.colorbar()
# import numpy as np
plt.contour(hdu1.data, colors='r', levels=np.linspace(1, 151, 5), alpha=1)

# plt.imshow(hdu2.data, vmin=-2.e-5, vmax=2.e-4, origin='lower')
plt.grid(color='white', ls='solid')
plt.xlabel('Galactic Longitude')
plt.ylabel('Galactic Latitude')
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / WCS for this file
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATEREF to '1990-06-01T21:06:50' from MJDREF.
# Invalid parameter values: MJD-OBS and DATE-OBS are inconsistent.
# Changed DATE-OBS from '06/05/94' to '1994-05-06''. [astropy.wcs.wcs]

# %%
np.linspace(0, 5, 10)
# Out:
# array([0.        , 0.55555556, 1.11111111, 1.66666667, 2.22222222,
#        2.77777778, 3.33333333, 3.88888889, 4.44444444, 5.        ])

# %%
print(image_data1.shape, image_data2.shape, image_data3.shape)
# Out:
# (512, 512) (4, 900, 1200) (3, 900, 1200)

# %%
image_data[0].shape
# Out:
# (900, 1200)

# %%
plt.figure()
plt.imshow(image_data1)#, cmap='gray') #Rosa 
plt.imshow(image_data2[0], alpha = 0.5, cmap='gray')
plt.colorbar()

# %%
# Python program to read
# image using matplotlib
 
# importing matplotlib modules
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
 
# Read Images
img = mpimg.imread("NGC3227_SDSS.png", img)
 
# Output Images
plt.figure()
#plt.imshow(image_data1, cmap='gray')
plt.imshow(image_data2[0], cmap='gray')

plt.imshow(img, alpha=0.5)
plt.colorbar()
